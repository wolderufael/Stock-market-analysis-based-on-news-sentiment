# %% [markdown]
# # Calculating Stock Market Price Technical Indicators of Apple,MicroSoft,Google,Meta,Nvidia,Amazon and Tesla Using TA-Lib

# %%
import os
import sys
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib as px

# %%
# Get the current working directory (where the notebook is running)
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)
print(os.getcwd())
# Out:
# g:\Programming\10_Academy\Week 01\Stock-market-analysis-based-on-news-sentiment

# %%
from scripts.stock_analyzer import StockAnalyzer

# %% [markdown]
# ### Apple's Stock Price Historical Data

# %% [markdown]
# **Get the day range from the headline analysis output data**

# %%
headline_df=pd.read_csv('Data\\sentiment_data.csv')

# %%
#get the day range 
filtered_headline=headline_df[headline_df['stock']=='AAPL']
max_date = filtered_headline['date_only'].max()
min_date = filtered_headline['date_only'].min()

print("Max date:", max_date)
print("Min date:", min_date)
# Out:
# Max date: 2020-06-10
# Min date: 2020-03-09

# %%
#instance of our analyser class using the day range
analyzer = StockAnalyzer('AAPL','2020-03-09','2020-06-10')

# %%
#retrieve data using yfinance
apple_stock_data=analyzer.retrieve_stock_data()
apple_stock_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-03-09  65.937500  69.522499  65.750000  66.542503  64.736038  286744800
# 2020-03-10  69.285004  71.610001  67.342499  71.334999  69.398430  285290000
# 2020-03-11  69.347504  70.305000  67.964996  68.857498  66.988205  255598800
# 2020-03-12  63.985001  67.500000  62.000000  62.057499  60.372791  418474000
# 2020-03-13  66.222504  69.980003  63.237499  69.492500  67.605949  370732000
# ...               ...        ...        ...        ...        ...        ...
# 2020-06-03  81.165001  81.550003  80.574997  81.279999  79.287506  104491200
# 2020-06-04  81.097504  81.404999  80.195000  80.580002  78.604668   87560400
# 2020-06-05  80.837502  82.937500  80.807503  82.875000  80.843391  137250400
# 2020-06-08  82.562500  83.400002  81.830002  83.364998  81.321396   95654400
# ...

# %%
# Calculate technical indicators
stock_data_indicators = analyzer.calculate_technical_indicators(apple_stock_data)
stock_data_indicators.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-06-03  81.165001  81.550003  80.574997  81.279999  79.287506  104491200
# 2020-06-04  81.097504  81.404999  80.195000  80.580002  78.604668   87560400
# 2020-06-05  80.837502  82.937500  80.807503  82.875000  80.843391  137250400
# 2020-06-08  82.562500  83.400002  81.830002  83.364998  81.321396   95654400
# 2020-06-09  83.035004  86.402496  83.002502  85.997498  83.889366  147712400
#
#                   SMA        RSI        EMA      MACD  MACD_Signal
# Date
# 2020-06-03  78.627876  68.538887  78.126181  2.443072     2.593375
# 2020-06-04  78.899001  64.613988  78.359878  2.350095     2.544719
# 2020-06-05  79.246001  70.565405  78.789890  2.433545     2.522484
# 2020-06-08  79.537626  71.661291  79.225614  2.510281     2.520043
# 2020-06-09  79.899875  76.683830  79.870556  2.751795     2.566394

# %%
# Plot stock data
analyzer.plot_technical_indicators(apple_stock_data)

# %%
# save the out put data
apple_stock_data.to_csv('Data/Output/apple_stock_data.csv', index=False)

# %% [markdown]
# ### Google's Stock Price Historical Data

# %%
#get the day range 
filtered_headline=headline_df[headline_df['stock']=='GOOG']
max_date = filtered_headline['date_only'].max()
min_date = filtered_headline['date_only'].min()

print("Max date:", max_date)
print("Min date:", min_date)
# Out:
# Max date: 2020-06-10
# Min date: 2018-11-13

# %%
#instance of our analyser class using the day range
analyzer = StockAnalyzer('GOOG','2018-11-13','2020-06-10')

# %%
#retrieve data using yfinance
google_stock_data=analyzer.retrieve_stock_data()
google_stock_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-11-13  52.164501  52.830250  51.557499  51.802502  51.743618  30274000
# 2018-11-14  52.500000  52.728199  51.549999  52.182999  52.123684  31318000
# 2018-11-15  52.235500  53.592499  51.589001  53.235500  53.174988  36722000
# 2018-11-16  52.970501  53.349998  52.449001  53.074501  53.014172  33162000
# 2018-11-19  52.860001  53.039501  50.813000  51.000000  50.942032  37172000

# %%
# Calculate technical indicators
stock_data_indicators = analyzer.calculate_technical_indicators(google_stock_data)
stock_data_indicators.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2020-06-03  71.915001  72.327599  71.488853  71.819000  71.737366  25124000
# 2020-06-04  71.519997  71.947998  70.236504  70.609001  70.528740  29686000
# 2020-06-05  70.658501  72.252502  70.300003  71.919502  71.837753  34698000
# 2020-06-08  71.116997  72.399498  71.116997  72.330498  72.248283  28084000
# 2020-06-09  72.267998  73.400002  72.160500  72.807999  72.725243  28184000
#
#                   SMA        RSI        EMA      MACD  MACD_Signal
# Date
# 2020-06-03  69.827938  66.602102  69.598734  1.824630     1.844852
# 2020-06-04  69.990138  58.926016  69.694950  1.684359     1.812754
# 2020-06-05  70.154713  63.793213  69.906812  1.659807     1.782164
# 2020-06-08  70.300313  65.186511  70.137639  1.654441     1.756620
# 2020-06-09  70.432563  66.785704  70.391959  1.669475     1.739191

# %%
# Plot stock data
analyzer.plot_technical_indicators(google_stock_data)

# %%
# save the out put data
google_stock_data.to_csv('Data/Output/google_stock_data.csv', index=False)

# %% [markdown]
# ### Amazon's Stock Price Historical Data

# %%
#get the day range 
filtered_headline=headline_df[headline_df['stock']=='AMZN']
max_date = filtered_headline['date_only'].max()
min_date = filtered_headline['date_only'].min()
print("Max date:", max_date)
print("Min date:", min_date)
# Out:
# Max date: 2020-06-10
# Min date: 2020-04-27

# %%
#instance of our analyser class using the day range
analyzer = StockAnalyzer('AMZN','2020-04-27','2020-06-10')

# %%
#retrieve data using yfinance
amazon_stock_data=analyzer.retrieve_stock_data()
amazon_stock_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-27  122.160004  122.244003  118.150002  118.800003  118.800003
# 2020-04-28  118.605003  118.675003  115.300003  115.704002  115.704002
# 2020-04-29  116.500504  119.594498  115.500000  118.635498  118.635498
# 2020-04-30  120.991997  123.750000  119.800499  123.699997  123.699997
# 2020-05-01  116.839996  118.122002  112.909500  114.302002  114.302002
#
#                Volume
# Date
# 2020-04-27  112912000
# 2020-04-28  105388000
# 2020-04-29   91832000
# 2020-04-30  190692000
# 2020-05-01  195452000

# %%
# Calculate technical indicators
stock_data_indicators = analyzer.calculate_technical_indicators(amazon_stock_data)
stock_data_indicators.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-03  123.400497  124.400002  123.058502  123.919998  123.919998
# 2020-06-04  123.871498  125.376999  122.500504  123.029999  123.029999
# 2020-06-05  122.225502  124.432503  121.856499  124.150002  124.150002
# 2020-06-08  125.010002  126.500000  124.366997  126.203003  126.203003
# 2020-06-09  126.472000  131.321503  126.250000  130.042999  130.042999
#
#                Volume         SMA        RSI         EMA  MACD  MACD_Signal
# Date
# 2020-06-03   53420000  120.964251  57.404841  120.885562   NaN          NaN
# 2020-06-04   58974000  121.237600  54.949079  121.089794   NaN          NaN
# 2020-06-05   66128000  121.526075  57.417842  121.381243   NaN          NaN
# 2020-06-08   79414000  121.887201  61.574551  121.840458   NaN          NaN
# 2020-06-09  103520000  122.366851  67.888594  122.621652   NaN          NaN

# %%
# Plot stock data
analyzer.plot_technical_indicators(amazon_stock_data)

# %%
# save the out put data
amazon_stock_data.to_csv('Data/Output/amazon_stock_data.csv', index=False)

# %% [markdown]
# ### Tesla's Stock Price Historical Data

# %%
#get the day range 
filtered_headline=headline_df[headline_df['stock']=='TSLA']
max_date = filtered_headline['date_only'].max()
min_date = filtered_headline['date_only'].min()
print("Max date:", max_date)
print("Min date:", min_date)
# Out:
# Max date: 2020-06-10
# Min date: 2019-07-01

# %%
#instance of our analyser class using the day range
analyzer = StockAnalyzer('TSLA','2020-03-09','2020-06-10')

# %%
#retrieve data using yfinance
tesla_stock_data=analyzer.retrieve_stock_data()
tesla_stock_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-03-09  40.359333  44.200001  40.333332  40.533333  40.533333  256105500
# 2020-03-10  43.962002  44.533333  40.533333  43.021999  43.021999  233916000
# 2020-03-11  42.680000  43.571999  40.866669  42.282001  42.282001  199837500
# 2020-03-12  38.726002  39.633331  36.416668  37.369999  37.369999  283636500
# 2020-03-13  39.666668  40.504665  33.466667  36.441334  36.441334  339604500

# %%
# Calculate technical indicators
stock_data_indicators = analyzer.calculate_technical_indicators(tesla_stock_data)
stock_data_indicators.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-06-03  59.208000  59.862667  58.673332  58.863998  58.863998  119242500
# 2020-06-04  59.325333  59.716667  57.229332  57.625332  57.625332  133315500
# 2020-06-05  58.522667  59.101334  57.746666  59.043999  59.043999  117178500
# 2020-06-08  61.266666  63.333332  60.610668  63.327999  63.327999  212620500
# 2020-06-09  62.667332  63.629333  61.595333  62.711334  62.711334  170823000
#
#                   SMA        RSI        EMA      MACD  MACD_Signal
# Date
# 2020-06-03  54.734700  65.908527  54.549542  2.783677     2.730525
# 2020-06-04  55.007366  61.498514  54.842474  2.700911     2.724603
# 2020-06-05  55.359433  64.433775  55.242619  2.718457     2.723373
# 2020-06-08  55.794433  71.499745  56.012656  3.042967     2.787292
# 2020-06-09  56.225700  69.363508  56.650625  3.213343     2.872502

# %%
# Plot stock data
analyzer.plot_technical_indicators(tesla_stock_data)

# %%
# save the out put data
tesla_stock_data.to_csv('Data/Output/tesla_stock_data.csv', index=False)
