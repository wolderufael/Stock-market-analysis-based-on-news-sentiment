# %% [markdown]
# # Calculating Stock Market Price Technical Indicators of Apple Using TA-Lib

# %%
import os
import sys
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib as px

# %%
# Get the current working directory (where the notebook is running)
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)
print(os.getcwd())
# Out:
# g:\Programming\10_Academy\Week 01\Stock-market-analysis-based-on-news-sentiment

# %%
from scripts.stock_analyzer import StockAnalyzer

# %% [markdown]
# ### Apple's Stock Price Historical Data

# %% [markdown]
# ### we are interested on the data starting from 2020-03-09 to 2020-06-10 for later correlation analysis with news head line

# %%
analyzer = StockAnalyzer('AAPL','2020-03-09','2020-06-10')

# %%
stock_data=analyzer.retrieve_stock_data()
stock_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-03-09  65.937500  69.522499  65.750000  66.542503  64.736053  286744800
# 2020-03-10  69.285004  71.610001  67.342499  71.334999  69.398430  285290000
# 2020-03-11  69.347504  70.305000  67.964996  68.857498  66.988205  255598800
# 2020-03-12  63.985001  67.500000  62.000000  62.057499  60.372795  418474000
# 2020-03-13  66.222504  69.980003  63.237499  69.492500  67.605949  370732000
# ...               ...        ...        ...        ...        ...        ...
# 2020-06-03  81.165001  81.550003  80.574997  81.279999  79.287498  104491200
# 2020-06-04  81.097504  81.404999  80.195000  80.580002  78.604675   87560400
# 2020-06-05  80.837502  82.937500  80.807503  82.875000  80.843399  137250400
# 2020-06-08  82.562500  83.400002  81.830002  83.364998  81.321388   95654400
# 2020-06-09  83.035004  86.402496  83.002502  85.997498  83.889351  147712400
#
# [65 rows x 6 columns]

# %%
# Calculate technical indicators
stock_data_indicators = analyzer.calculate_technical_indicators(stock_data)
stock_data_indicators.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-06-03  81.165001  81.550003  80.574997  81.279999  79.287498  104491200
# 2020-06-04  81.097504  81.404999  80.195000  80.580002  78.604675   87560400
# 2020-06-05  80.837502  82.937500  80.807503  82.875000  80.843399  137250400
# 2020-06-08  82.562500  83.400002  81.830002  83.364998  81.321388   95654400
# 2020-06-09  83.035004  86.402496  83.002502  85.997498  83.889351  147712400
#
#                   SMA        RSI        EMA      MACD  MACD_Signal
# Date
# 2020-06-03  78.627876  68.538887  78.126181  2.443072     2.593375
# 2020-06-04  78.899001  64.613988  78.359878  2.350095     2.544719
# 2020-06-05  79.246001  70.565405  78.789890  2.433545     2.522484
# 2020-06-08  79.537626  71.661291  79.225614  2.510281     2.520043
# 2020-06-09  79.899875  76.683830  79.870556  2.751795     2.566394

# %%
# Plot stock data
analyzer.plot_technical_indicators(stock_data)
